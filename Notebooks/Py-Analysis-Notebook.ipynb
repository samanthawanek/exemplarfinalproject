# %%
import pandas as pd

# %%
mydata = pd.read_excel("../Data/DATA.xlsx")

# %%
pd.set_option('display.max_columns', 1000)

# %%
mydata
# Out:
#      'ID Number' 'Status'    'Type'  'Aluminum'  'Antimony'  'Arsenic'  \
# 0              1    'ASD'   'Child'         7.0    0.200000       11.0
# 1              3    'ASD'   'Child'        19.0    0.200000        8.1
# 2              5    'ASD'   'Child'         9.2    0.000057        5.9
# 3              6    'ASD'   'Child'         8.4    0.000057       14.0
# 4              8    'ASD'   'Child'         5.6    0.000028       11.0
# ..           ...      ...       ...         ...         ...        ...
# 100           66     'TD'  'Mother'         5.1    0.000113        5.2
# 101           67     'TD'  'Mother'         5.4    0.000113        4.7
# 102           68     'TD'  'Mother'         1.6    0.000057       42.0
# 103           70     'TD'  'Mother'         9.9    0.000113        5.2
# 104           71     'TD'  'Mother'         2.4    0.000057       15.0
#
#      'Barium'  'Beryllium'  'Bismuth'  'Cadmium'  'Cesium'  'Gadolinium'  \
# ...
