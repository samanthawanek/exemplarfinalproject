# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Urinary Essential Elements of Young Children with Autism Spectrum Disorder (ASD) and their Mothers
#
# - [Mendeley Reference](https://data.mendeley.com/datasets/79fk29dvk6/1)
# - [Science Direct Reference](https://www.sciencedirect.com/science/article/abs/pii/S1750946720300088?via%3Dihub)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %% [markdown]
# ### Table of Contents <a class="anchor" id="PAN_toc"></a>
#
# * [Table of Contents](#PAN_toc)
#     * [Page 1 - Abstract](#PAN_page_1)
#     * [Page 2 - Imported Libraries](#PAN_page_2)
#     * [Page 3 - Import the Dataset](#PAN_page_3)
#     * [Page 4 - Setting Notebook Options](#PAN_page_4)
#     * [Page 5 - Looking at the Data](#PAN_page_5)
#     * [Page 6 - Checking the Column Names](#PAN_page_6)
#     * [Page 7 - Cleaning the Column Names](#PAN_page_7)
#     * [Page 8 - Counting Columns](#PAN_page_8)
#     * [Page 9 - Getting Info about the Dataset](#PAN_page_9)
#     * [Page 10 - Get Descriptive Statistics about the Dataset](#PAN_page_10)
#     * [Page 11 - Counting Rows and Removing any NANs](#PAN_page_11)
#     * [Page 12 - Q1: Does the increase of toxic elements or decrease of essential elements predict the status of ASD?](#PAN_page_12)
#     * [Page 13 - Q1: Analysis -Multiple Stepwise Regression - Backwards](#PAN_page_13)
#     * [Page 14 - Creating a new Cleaned Dataset](#PAN_page_14)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 1 - Abstract <a class="anchor" id="PAN_page_1"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %% [markdown]
# ### Background
# Even though the cause of autism spectrum disorders (ASD) remains unknown, the current understanding points towards complex interactions between environmental and genetic factors. One important environmental factor to consider is intake of toxic and essential elements, and their role in metabolism. Essential elements have received considerably less attention in the literature than the presence of toxins in urine.
#
# ### Method
# The purpose of this investigation is to comprehensively assess the association between urinary element compositions of 28 mothers who had young children with ASD and 29 mothers who had young typically developing (TD) children, and in a subset of their children (21 with ASD and 26 TD).
#
# ### Questions
# 1. Does the increase of toxic elements or decrease of essential elements (IV's) predict the status of ASD (DV)?
# 2. How does the urine test differ (Toxic vs Essential) for kids with Autism (ASD) to Typically Developing kids (TD)?
# 3. How does the urine test differ (Toxic vs Essential) for mothers with Autism (ASD) to Typically Developing moms (TD)?
# 4. How does the urine test differ (Toxic vs Essential) for kids with Autism (ASD) to their moms with Autism(ASD)?
#
# ### Analysis Setup
# DV1 = Status with 2 levels (ASD or TD)<br>
# DV2 = Type with 2 levels (Child or Mother)<br>
# IV1 = Group of 20 Toxic elements (Aluminum to Uranium) <br>
# IV2 = Group of 19 Essential elements (Boron to Creatinine)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 2 - Imported Libraries<a class="anchor" id="PAN_page_2"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %%
install.packages("readxl")
# Out:
# Installing package into 'C:/Users/rache/AppData/Local/R/win-library/4.2'
# (as 'lib' is unspecified)
# package 'readxl' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\rache\AppData\Local\Temp\RtmpiYd19K\downloaded_packages

# %%
library("mvnormtest")                   #test for multivariate normality
library("car")                          #run the MANOVA test and other assumption testing
library("IDPmisc")                      #remove missing data for Shapiro test
library("multcomp")                     #conducting post hocs for ANCOVAs
library("dplyr")                        #calculate means
library("readxl")
library("tidyr")
library("ggplot2")
# Out:
# Warning message:
# "package 'car' was built under R version 4.2.2"
# Loading required package: carData
#
# Warning message:
# "package 'carData' was built under R version 4.2.2"
# Warning message:
# "package 'IDPmisc' was built under R version 4.2.2"
# Warning message:
# "package 'multcomp' was built under R version 4.2.2"
# Loading required package: mvtnorm
#
# Loading required package: survival
#
# Loading required package: TH.data
#
# Loading required package: MASS
#
#
# Attaching package: 'TH.data'
#
#
# The following object is masked from 'package:MASS':
#
#     geyser
#
#
# Warning message:
# "package 'dplyr' was built under R version 4.2.2"
#
# Attaching package: 'dplyr'
#
#
# The following object is masked from 'package:MASS':
#
#     select
#
#
# The following object is masked from 'package:car':
#
#     recode
#
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# Warning message:
# "package 'readxl' was built under R version 4.2.3"
# Warning message:
# "package 'tidyr' was built under R version 4.2.2"
# Warning message:
# "package 'ggplot2' was built under R version 4.2.2"

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 3 - Import the Dataset <a class="anchor" id="PAN_page_3"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %%
#import data from Data folder
data <- read_excel("../Data/DATA.xlsx")

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 4 - Setting Notebook Options<a class="anchor" id="PAN_page_4"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %%
# set max columns and rows
options(repr.matrix.max.cols=1000)
options(max.print = 105) # set the maximum number of rows to 105
options(repr.matrix.max.rows=105)

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 5 - Looking at the Data<a class="anchor" id="PAN_page_5"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %%
data
# Out:
#     'ID Number' 'Status' 'Type'   'Aluminum'   'Antimony'   'Arsenic'
# 1    1          'ASD'    'Child'   7.000000000 2.000000e-01 1.100000e+01
# 2    3          'ASD'    'Child'  19.000000000 2.000000e-01 8.100000e+00
#     'Barium'     'Beryllium'  'Bismuth'    'Cadmium'    'Cesium' 'Gadolinium'
# 1   2.100000e+00 0.0007071068 1.131371e-04 1.414214e-04  4.3     9.899495e-05
# 2   8.000000e+00 0.0003535534 5.656854e-05 7.071068e-05 16.0     4.949747e-05
#     'Lead'       'Mercury'    'Nickel'     'Palladium'  'Platinum'
# 1   2.000000e-01 0.0004242641 4.900000e+00 0.0008485281 1.131371e-04
# 2   1.000000e+00 0.0002121320 2.900000e+00 0.0004242641 5.656854e-05
#     'Tellurium'  'Thallium'   'Thorium'    'Tin'        'Tungsten'
# 1   0.0005656854 1.000000e-01 4.242641e-05 1.600000e+00 3.000000e-01
# 2   0.0002828427 6.000000e-01 2.121320e-05 1.000000e+00 2.000000e-01
#     'Uranium'    'Boron' 'Calcium' 'Chromium'   'Cobalt'     'Copper'
# 1   7.071068e-05  2.30   140.0     0.0004242641 0.0011313708 0.014
# 2   3.535534e-05  4.90    81.0     0.0002121320 0.0005656854 0.018
#     'Iron'     'Lithium' 'Magnesium' 'Manganese'  'Molybdenum' 'Phosphorus'
# 1   0.24000000 0.083     200         0.0007000000 0.130        1180
# 2   0.20000000 0.170     170         0.0050000000 0.180         360
#     'Potassium' 'Selenium' 'Sodium' 'Strontium' 'Sulfur' 'Vanadium'   'Zinc'
# 1    24         0.110       56      0.130        680     0.0002828427 0.660
# 2   120         0.094      290      0.170        860     0.0005000000 0.480
#     'Creatinine'
# 1   175.0
# 2    76.0
#  [ reached getOption("max.print") -- omitted 103 rows ]

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 6 - Checking the Column Names<a class="anchor" id="PAN_page_6"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %%
# check the column names - notice the extra ' single quote
names(data)
# Out:
#  [1] "'ID Number'"  "'Status'"     "'Type'"       "'Aluminum'"   "'Antimony'"
#  [6] "'Arsenic'"    "'Barium'"     "'Beryllium'"  "'Bismuth'"    "'Cadmium'"
# [11] "'Cesium'"     "'Gadolinium'" "'Lead'"       "'Mercury'"    "'Nickel'"
# [16] "'Palladium'"  "'Platinum'"   "'Tellurium'"  "'Thallium'"   "'Thorium'"
# [21] "'Tin'"        "'Tungsten'"   "'Uranium'"    "'Boron'"      "'Calcium'"
# [26] "'Chromium'"   "'Cobalt'"     "'Copper'"     "'Iron'"       "'Lithium'"
# [31] "'Magnesium'"  "'Manganese'"  "'Molybdenum'" "'Phosphorus'" "'Potassium'"
# [36] "'Selenium'"   "'Sodium'"     "'Strontium'"  "'Sulfur'"     "'Vanadium'"
# [41] "'Zinc'"       "'Creatinine'"

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 7 - Cleaning the Column Names<a class="anchor" id="PAN_page_7"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %%
# Remove the extra quotes from the column names
colnames(data) <- gsub("'", "", colnames(data))

# Print the cleaned data frame with the updated column names
names(data)
# Out:
#  [1] "ID Number"  "Status"     "Type"       "Aluminum"   "Antimony"
#  [6] "Arsenic"    "Barium"     "Beryllium"  "Bismuth"    "Cadmium"
# [11] "Cesium"     "Gadolinium" "Lead"       "Mercury"    "Nickel"
# [16] "Palladium"  "Platinum"   "Tellurium"  "Thallium"   "Thorium"
# [21] "Tin"        "Tungsten"   "Uranium"    "Boron"      "Calcium"
# [26] "Chromium"   "Cobalt"     "Copper"     "Iron"       "Lithium"
# [31] "Magnesium"  "Manganese"  "Molybdenum" "Phosphorus" "Potassium"
# [36] "Selenium"   "Sodium"     "Strontium"  "Sulfur"     "Vanadium"
# [41] "Zinc"       "Creatinine"

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumBlue;background-color:MediumBlue">
#
# # Page 8 - Counting Columns <a class="anchor" id="PAN_page_8"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumBlue;background-color:MediumBlue">

# %%
# Count the number of columns
num_cols = ncol(data)

print(num_cols)
# Out:
# [1] 42

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 9 - Get Info about the Dataset<a class="anchor" id="PAN_page_9"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %%
str(data)
# Out:
# tibble [105 × 42] (S3: tbl_df/tbl/data.frame)
#  $ ID Number : num [1:105] 1 3 5 6 8 10 12 17 19 20 ...
#  $ Status    : chr [1:105] "'ASD'" "'ASD'" "'ASD'" "'ASD'" ...
#  $ Type      : chr [1:105] "'Child'" "'Child'" "'Child'" "'Child'" ...
#  $ Aluminum  : num [1:105] 7 19 9.2 8.4 5.6 17 9.5 6.8 24 21 ...
#  $ Antimony  : num [1:105] 2.00e-01 2.00e-01 5.66e-05 5.66e-05 2.83e-05 ...
#  $ Arsenic   : num [1:105] 11 8.1 5.9 14 11 15 120 35 14 12 ...
#  $ Barium    : num [1:105] 2.1 8 4.7 3 3.8 3.1 4.2 4 2.6 1.8 ...
#  $ Beryllium : num [1:105] 0.000707 0.000354 0.000354 0.000354 0.000177 ...
#  $ Bismuth   : num [1:105] 1.13e-04 5.66e-05 2.00e-01 5.66e-05 2.83e-05 ...
#  $ Cadmium   : num [1:105] 1.41e-04 7.07e-05 7.07e-05 7.07e-05 3.54e-05 ...
#  $ Cesium    : num [1:105] 4.3 16 11 16 4.5 10 5.7 3.3 4.4 3.6 ...
#  $ Gadolinium: num [1:105] 9.90e-05 4.95e-05 4.95e-05 4.95e-05 2.47e-05 ...
#  $ Lead      : num [1:105] 0.2 1 0.5 0.9 0.4 0.5 0.3 0.4 0.5 0.1 ...
#  $ Mercury   : num [1:105] 0.000424 0.000212 0.000212 0.000212 1 ...
#  $ Nickel    : num [1:105] 4.9 2.9 9.4 15 2.5 5.2 6.7 9.7 3.8 1.3 ...
#  $ Palladium : num [1:105] 0.000849 0.000424 0.000424 0.000424 0.000212 ...
#  $ Platinum  : num [1:105] 1.13e-04 5.66e-05 5.66e-05 5.66e-05 2.83e-05 ...
#  $ Tellurium : num [1:105] 0.000566 0.000283 0.000283 0.000283 0.000141 ...
#  $ Thallium  : num [1:105] 0.1 0.6 0.3 0.4 0.4 0.2 0.3 0.09 0.6 0.2 ...
#  $ Thorium   : num [1:105] 4.24e-05 2.12e-05 2.12e-05 2.12e-05 1.06e-05 ...
#  $ Tin       : num [1:105] 1.6 1 8.4 1.4 0.6 0.5 0.2 4 2 0.2 ...
#  $ Tungsten  : num [1:105] 0.3 0.2 0.6 0.3 0.3 0.1 0.3 1.2 0.07 0.2 ...
#  $ Uranium   : num [1:105] 7.07e-05 3.54e-05 3.54e-05 3.54e-05 1.77e-05 ...
#  $ Boron     : num [1:105] 2.3 4.9 2.9 8.6 1.3 4.5 3.8 2.2 4.5 2.4 ...
#  $ Calcium   : num [1:105] 140 81 300 200 62 250 340 170 150 38 ...
#  $ Chromium  : num [1:105] 0.000424 0.000212 0.0006 0.001 0.001 ...
#  $ Cobalt    : num [1:105] 0.001131 0.000566 0.003 0.000566 0.000283 ...
#  $ Copper    : num [1:105] 0.014 0.018 0.021 0.024 0.022 0.019 0.018 0.018 0.02 0.02 ...
#  $ Iron      : num [1:105] 0.24 0.2 0.6 0.43 0.0354 ...
#  $ Lithium   : num [1:105] 0.083 0.17 0.17 0.061 0.22 0.12 0.083 0.14 0.084 0.055 ...
#  $ Magnesium : num [1:105] 200 170 310 390 170 180 230 120 110 150 ...
#  $ Manganese : num [1:105] 7e-04 5e-03 4e-03 5e-03 7e-03 2e-03 2e-03 4e-04 6e-03 2e-03 ...
#  $ Molybdenum: num [1:105] 0.13 0.18 0.17 0.043 0.085 0.11 0.1 0.14 0.058 0.083 ...
#  $ Phosphorus: num [1:105] 1180 360 1860 150 910 1200 1320 260 810 900 ...
#  $ Potassium : num [1:105] 24 120 120 120 180 54 45 14 120 51 ...
#  $ Selenium  : num [1:105] 0.11 0.094 0.11 0.069 0.14 0.18 0.13 0.089 0.091 0.1 ...
#  $ Sodium    : num [1:105] 56 290 240 190 190 330 120 91 200 45 ...
#  $ Strontium : num [1:105] 0.13 0.17 0.37 0.33 0.12 0.24 0.29 0.35 0.26 0.06 ...
#  $ Sulfur    : num [1:105] 680 860 1050 630 1290 800 1090 670 690 990 ...
#  $ Vanadium  : num [1:105] 0.000283 0.0005 0.0006 0.0004 0.0008 ...
#  $ Zinc      : num [1:105] 0.66 0.48 0.75 0.24 0.27 1.1 0.66 0.69 0.74 0.5 ...
#  $ Creatinine: num [1:105] 175 76 58.6 54.3 30.6 70.6 82.1 172 87.4 123 ...

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 10 - Get Descriptive Statistics about the Dataset<a class="anchor" id="PAN_page_10"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %% [markdown]
# # Descriptive statistics:
# Basic descriptive statistics such as mean, median, mode, standard deviation, variance, range, and percentiles can be computed for each element to summarize its distribution.

# %%
summary(data)
# Out:
#    ID Number        Status              Type              Aluminum
#  Min.   : 1.00   Length:105         Length:105         Min.   : 0.00141
#  1st Qu.:22.00   Class :character   Class :character   1st Qu.: 2.50000
#     Antimony            Arsenic              Barium
#  Min.   :0.0000283   Min.   :  0.00106   Min.   : 0.000071
#  1st Qu.:0.0000566   1st Qu.:  5.00000   1st Qu.: 1.100000
#    Beryllium            Bismuth             Cadmium              Cesium
#  Min.   :0.0001768   Min.   : 0.000028   Min.   :0.0000354   Min.   : 1.200
#  1st Qu.:0.0003536   1st Qu.: 0.000057   1st Qu.:0.0000707   1st Qu.: 3.000
#    Gadolinium            Lead              Mercury              Nickel
#  Min.   : 0.00002   Min.   :0.0000707   Min.   :0.0001061   Min.   :3.54e-04
#  1st Qu.: 0.00005   1st Qu.:0.2000000   1st Qu.:0.0002121   1st Qu.:2.10e+00
#    Palladium            Platinum           Tellurium
#  Min.   :0.0002121   Min.   :2.828e-05   Min.   :0.0001414
#  1st Qu.:0.0004243   1st Qu.:5.657e-05   1st Qu.:0.0002828
#     Thallium            Thorium               Tin              Tungsten
#  Min.   :0.0000354   Min.   :1.061e-05   Min.   :0.000057   Min.   :0.0000354
#  1st Qu.:0.1000000   1st Qu.:2.121e-05   1st Qu.:0.300000   1st Qu.:0.0700000
#     Uranium              Boron           Calcium         Chromium
#  Min.   :1.768e-05   Min.   : 0.480   Min.   :  4.2   Min.   :0.0001061
#  1st Qu.:3.536e-05   1st Qu.: 1.100   1st Qu.: 62.0   1st Qu.:0.0002121
#      Cobalt              Copper             Iron            Lithium
#  Min.   :0.0002828   Min.   :0.00600   Min.   :0.03536   Min.   :0.00900
#  1st Qu.:0.0005657   1st Qu.:0.00900   1st Qu.:0.14000   1st Qu.:0.04400
#    Magnesium     Manganese           Molybdenum        Phosphorus
#  Min.   : 17   Min.   :0.0001414   Min.   :0.00300   Min.   : 150.0
#  1st Qu.: 66   1st Qu.:0.0007000   1st Qu.:0.03500   1st Qu.: 550.0
#    Potassium         Selenium           Sodium        Strontium
#  Min.   : 10.00   Min.   :0.02100   Min.   : 21.0   Min.   :0.019
#  1st Qu.: 20.00   1st Qu.:0.04100   1st Qu.: 65.0   1st Qu.:0.100
#      Sulfur          Vanadium              Zinc          Creatinine
#  Min.   : 290.0   Min.   :0.0001414   Min.   :0.0520   Min.   : 10.6
#  1st Qu.: 470.0   1st Qu.:0.0001414   1st Qu.:0.2300   1st Qu.: 71.8
#  [ reached getOption("max.print") -- omitted 4 rows ]

# %%
#Distribution of Status Variable
table(data$Status)
# Out:
# 'ASD'  'TD'
#    50    55

# %%
#Distribution of Type Variable
table(data$Type)
# Out:
#  'Child' 'Mother'
#       47       58

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 11 - Counting Rows and Removing any NANs<a class="anchor" id="PAN_page_11"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %%
#Count the number of rows using nrow()
print(nrow(data))
# Out:
# [1] 105

# %%
#Drop rows with missing values if there are any
data = na.omit(data)

# %%
#Recount the number of rows to assess any losses after dropping missing data
print(nrow(data))
# Out:
# [1] 105

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 12 - Q1: Does the increase of toxic elements or decrease of essential elements predict the status of ASD? <a class="anchor" id="PAN_page_12"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %% [markdown]
# # Subgroup Analysis:
# The data captured urine test results for ASD and TD kids, as well as their ASD or TD mothers. Before analyzing which elements have the greatest influence on the prediction of ASD in either kids or moms, we must first start by evaluating correlations for each subgroup within the subsets of TOXIC and ESSENTIAL elements as generational factors might also be present in the data.
#
# # Subgroups:
# (1) childToxic: Child ASD & TD       + (1) childEssential1: Child ASD & TD <br>
# (1) motherToxic: Mother ASD & TD        + (1) motherEssential: Mother ASD & TD N<br>
# (1) ASD_Toxic: Child ASD & Mother ASD + (1) ASD_Essenstial: Child ASD + Mother ASD<br>
# (1) TD_Toxic: Child TD & Mother TD   + (1) TD_Essential: Child TD & Mother TD<br>

# %% [markdown]
# # Set up Subgroup Data

# %%
# Drop the first column since we don't need ID Number
data1 <- data %>% select(-c(1))

# %%
unique(data$Status)
# Out:
# [1] "'ASD'" "'TD'"

# %%
unique(data$Type)
# Out:
# [1] "'Child'"  "'Mother'"

# %%
#Recoding IV - Status into numeric
data$Status[data$Status == '\'ASD\''] <- 0
data$Status[data$Status == '\'TD\''] <- 1

# %%
#Recoding IV-Type into numeric 
data$Type[data$Type == '\'Child\''] <- 0
data$Type[data$Type == '\'Mother\''] <- 1

# %%
data1
# Out:
#     Status Type Aluminum     Antimony     Arsenic      Barium
# 1   0      0     7.000000000 2.000000e-01 1.100000e+01 2.100000e+00
# 2   0      0    19.000000000 2.000000e-01 8.100000e+00 8.000000e+00
#     Beryllium    Bismuth      Cadmium      Cesium Gadolinium   Lead
# 1   0.0007071068 1.131371e-04 1.414214e-04  4.3   9.899495e-05 2.000000e-01
# 2   0.0003535534 5.656854e-05 7.071068e-05 16.0   4.949747e-05 1.000000e+00
#     Mercury      Nickel       Palladium    Platinum     Tellurium
# 1   0.0004242641 4.900000e+00 0.0008485281 1.131371e-04 0.0005656854
# 2   0.0002121320 2.900000e+00 0.0004242641 5.656854e-05 0.0002828427
#     Thallium     Thorium      Tin          Tungsten     Uranium      Boron
# 1   1.000000e-01 4.242641e-05 1.600000e+00 3.000000e-01 7.071068e-05  2.30
# 2   6.000000e-01 2.121320e-05 1.000000e+00 2.000000e-01 3.535534e-05  4.90
#     Calcium Chromium     Cobalt       Copper Iron       Lithium Magnesium
# 1   140.0   0.0004242641 0.0011313708 0.014  0.24000000 0.083   200
# 2    81.0   0.0002121320 0.0005656854 0.018  0.20000000 0.170   170
#     Manganese    Molybdenum Phosphorus Potassium Selenium Sodium Strontium
# 1   0.0007000000 0.130      1180        24       0.110     56    0.130
# 2   0.0050000000 0.180       360       120       0.094    290    0.170
#     Sulfur Vanadium     Zinc  Creatinine
# 1    680   0.0002828427 0.660 175.0
# 2    860   0.0005000000 0.480  76.0
#  [ reached getOption("max.print") -- omitted 103 rows ]

# %%
# Create Subgroup: Child
child <- group_by(data1, Type) 
print(child)
# Out:
# # A tibble: 105 × 42
# # Groups:   Type [2]
#    ID Numb…¹ Status Type  Alumi…² Antim…³ Arsenic Barium Beryl…⁴ Bismuth Cadmium
#        <dbl> <chr>  <chr>   <dbl>   <dbl>   <dbl>  <dbl>   <dbl>   <dbl>   <dbl>
#  1         1 0      0         7   2   e-1    11      2.1 7.07e-4 1.13e-4 1.41e-4
#  2         3 0      0        19   2   e-1     8.1    8   3.54e-4 5.66e-5 7.07e-5
#  3         5 0      0         9.2 5.66e-5     5.9    4.7 3.54e-4 2   e-1 7.07e-5
#  4         6 0      0         8.4 5.66e-5    14      3   3.54e-4 5.66e-5 7.07e-5
#  5         8 0      0         5.6 2.83e-5    11      3.8 1.77e-4 2.83e-5 3.54e-5
#  6        10 0      0        17   6   e-1    15      3.1 3.54e-4 5.66e-5 7.07e-5
#  7        12 0      0         9.5 5.66e-5   120      4.2 3.54e-4 5.66e-5 2   e-1
#  8        17 0      0         6.8 2   e-1    35      4   7.07e-4 1.13e-4 1.41e-4
#  9        19 0      0        24   2   e-1    14      2.6 3.54e-4 5.66e-5 7.07e-5
# 10        20 0      0        21   7   e-2    12      1.8 3.54e-4 5.66e-5 2   e-1
# # … with 95 more rows, 32 more variables: Cesium <dbl>, Gadolinium <dbl>,
# #   Lead <dbl>, Mercury <dbl>, Nickel <dbl>, Palladium <dbl>, Platinum <dbl>,
# #   Tellurium <dbl>, Thallium <dbl>, Thorium <dbl>, Tin <dbl>, Tungsten <dbl>,
# #   Uranium <dbl>, Boron <dbl>, Calcium <dbl>, Chromium <dbl>, Cobalt <dbl>,
# #   Copper <dbl>, Iron <dbl>, Lithium <dbl>, Magnesium <dbl>, Manganese <dbl>,
# #   Molybdenum <dbl>, Phosphorus <dbl>, Potassium <dbl>, Selenium <dbl>,
# #   Sodium <dbl>, Strontium <dbl>, Sulfur <dbl>, Vanadium <dbl>, Zinc <dbl>, …

# %%
#Create Subgroup child with Toxic elements only
childToxic <-   (data1[0:47 , 2:23])
print(childtoxic)
# Out:
# # A tibble: 47 × 22
#    Status Type    Aluminum Antim…¹ Arsenic Barium Beryl…² Bismuth Cadmium Cesium
#    <chr>  <chr>      <dbl>   <dbl>   <dbl>  <dbl>   <dbl>   <dbl>   <dbl>  <dbl>
#  1 'ASD'  'Child'      7   2   e-1    11      2.1 7.07e-4 1.13e-4 1.41e-4    4.3
#  2 'ASD'  'Child'     19   2   e-1     8.1    8   3.54e-4 5.66e-5 7.07e-5   16
#  3 'ASD'  'Child'      9.2 5.66e-5     5.9    4.7 3.54e-4 2   e-1 7.07e-5   11
#  4 'ASD'  'Child'      8.4 5.66e-5    14      3   3.54e-4 5.66e-5 7.07e-5   16
#  5 'ASD'  'Child'      5.6 2.83e-5    11      3.8 1.77e-4 2.83e-5 3.54e-5    4.5
#  6 'ASD'  'Child'     17   6   e-1    15      3.1 3.54e-4 5.66e-5 7.07e-5   10
#  7 'ASD'  'Child'      9.5 5.66e-5   120      4.2 3.54e-4 5.66e-5 2   e-1    5.7
#  8 'ASD'  'Child'      6.8 2   e-1    35      4   7.07e-4 1.13e-4 1.41e-4    3.3
#  9 'ASD'  'Child'     24   2   e-1    14      2.6 3.54e-4 5.66e-5 7.07e-5    4.4
# 10 'ASD'  'Child'     21   7   e-2    12      1.8 3.54e-4 5.66e-5 2   e-1    3.6
# # … with 37 more rows, 12 more variables: Gadolinium <dbl>, Lead <dbl>,
# #   Mercury <dbl>, Nickel <dbl>, Palladium <dbl>, Platinum <dbl>,
# #   Tellurium <dbl>, Thallium <dbl>, Thorium <dbl>, Tin <dbl>, Tungsten <dbl>,
# #   Uranium <dbl>, and abbreviated variable names ¹​Antimony, ²​Beryllium

# %%
#Create Subgroup childEssential with Essential elements only
childEssential <- data1%>% select(Status, Type, Boron, Calcium, Chromium, Cobalt, Iron, Lithium, Magnesium, Manganese, Molybdenum, Phosphorus, Potassium, Selenium, Sodium, Strontium, Sulfur, Vanadium, Zinc, Creatinine)
print(childEssential)
# Out:
# # A tibble: 105 × 20
#    Status Type  Boron Calcium Chromium   Cobalt   Iron Lithium Magnesium Manga…¹
#    <chr>  <chr> <dbl>   <dbl>    <dbl>    <dbl>  <dbl>   <dbl>     <dbl>   <dbl>
#  1 0      0       2.3     140 0.000424 0.00113  0.24     0.083       200  0.0007
#  2 0      0       4.9      81 0.000212 0.000566 0.2      0.17        170  0.005
#  3 0      0       2.9     300 0.0006   0.003    0.6      0.17        310  0.004
#  4 0      0       8.6     200 0.001    0.000566 0.43     0.061       390  0.005
#  5 0      0       1.3      62 0.001    0.000283 0.0354   0.22        170  0.007
#  6 0      0       4.5     250 0.001    0.000566 0.53     0.12        180  0.002
#  7 0      0       3.8     340 0.0005   0.001    0.63     0.083       230  0.002
#  8 0      0       2.2     170 0.001    0.0009   0.3      0.14        120  0.0004
#  9 0      0       4.5     150 0.000212 0.000566 0.34     0.084       110  0.006
# 10 0      0       2.4      38 0.0004   0.000566 0.0707   0.055       150  0.002
# # … with 95 more rows, 10 more variables: Molybdenum <dbl>, Phosphorus <dbl>,
# #   Potassium <dbl>, Selenium <dbl>, Sodium <dbl>, Strontium <dbl>,
# #   Sulfur <dbl>, Vanadium <dbl>, Zinc <dbl>, Creatinine <dbl>, and abbreviated
# #   variable name ¹​Manganese

# %%
#Remove all "mother" rows
childEssential1 <- childEssential[0:47, ]
print(childEssential1)
# Out:
# # A tibble: 47 × 20
#    Status Type  Boron Calcium Chromium   Cobalt   Iron Lithium Magnesium Manga…¹
#    <chr>  <chr> <dbl>   <dbl>    <dbl>    <dbl>  <dbl>   <dbl>     <dbl>   <dbl>
#  1 0      0       2.3     140 0.000424 0.00113  0.24     0.083       200  0.0007
#  2 0      0       4.9      81 0.000212 0.000566 0.2      0.17        170  0.005
#  3 0      0       2.9     300 0.0006   0.003    0.6      0.17        310  0.004
#  4 0      0       8.6     200 0.001    0.000566 0.43     0.061       390  0.005
#  5 0      0       1.3      62 0.001    0.000283 0.0354   0.22        170  0.007
#  6 0      0       4.5     250 0.001    0.000566 0.53     0.12        180  0.002
#  7 0      0       3.8     340 0.0005   0.001    0.63     0.083       230  0.002
#  8 0      0       2.2     170 0.001    0.0009   0.3      0.14        120  0.0004
#  9 0      0       4.5     150 0.000212 0.000566 0.34     0.084       110  0.006
# 10 0      0       2.4      38 0.0004   0.000566 0.0707   0.055       150  0.002
# # … with 37 more rows, 10 more variables: Molybdenum <dbl>, Phosphorus <dbl>,
# #   Potassium <dbl>, Selenium <dbl>, Sodium <dbl>, Strontium <dbl>,
# #   Sulfur <dbl>, Vanadium <dbl>, Zinc <dbl>, Creatinine <dbl>, and abbreviated
# #   variable name ¹​Manganese

# %% [markdown]
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">
#
# # Page 13 - Q1 Analysis: Multiple Stepwise Regression - Backwards <a class="anchor" id="PAN_page_13"></a>
#
# [Back to Top](#PAN_toc)
#
# <hr style="height:5px;border-width:0;color:MediumAquamarine;background-color:MediumBlue">

# %% [markdown]
# ### Multiple Stepwise Regression - Backwards (full dataset)
# Evaluate which elements have the most influence over predicting the Status?

# %%
#Get a Baseline with a FitAll function to create a linear model of all 20 predictor variables
FitAll <- lm(Status ~ ., data=data1)
summary(FitAll)
# Out:
# Call:
# lm(formula = Status ~ ., data = data1)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.97256 -0.29636  0.03132  0.31330  0.78206
#
# Coefficients: (4 not defined because of singularities)
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -4.385e-01  4.274e-01  -1.026   0.3085
# Type1        4.162e-01  2.462e-01   1.690   0.0956 .
# Aluminum     1.077e-03  7.882e-03   0.137   0.8918
# Antimony    -8.279e-01  6.480e-01  -1.278   0.2058
# Arsenic     -1.233e-03  3.549e-03  -0.348   0.7293
# Barium       2.209e-02  4.462e-02   0.495   0.6221
# Beryllium    1.210e+03  6.283e+02   1.926   0.0583 .
# Bismuth      4.826e-02  3.331e-02   1.449   0.1520
# Cadmium     -5.786e-01  4.777e-01  -1.211   0.2300
# Cesium      -5.843e-02  3.251e-02  -1.797   0.0767 .
# Gadolinium  -2.726e-02  2.079e-02  -1.311   0.1942
# Lead         5.276e-01  2.755e-01   1.915   0.0597 .
# Mercury     -1.623e-01  2.599e-01  -0.624   0.5344
# Nickel      -2.945e-03  5.252e-02  -0.056   0.9554
# Palladium           NA         NA      NA       NA
# Platinum            NA         NA      NA       NA
# Tellurium           NA         NA      NA       NA
# Thallium    -9.671e-01  7.558e-01  -1.280   0.2050
# Thorium             NA         NA      NA       NA
# Tin          5.253e-02  3.809e-02   1.379   0.1724
# Tungsten     1.684e-01  2.741e-01   0.615   0.5409
#  [ reached getOption("max.print") -- omitted 20 rows ]
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.4607 on 68 degrees of freedom
# Multiple R-squared:  0.449,	Adjusted R-squared:  0.1572
# F-statistic: 1.539 on 36 and 68 DF,  p-value: 0.06312

# %%
#Backwards Elimination
step(FitAll, direction ='backward')
# Out:
# Start:  AIC=-134.37
# Status ~ Type + Aluminum + Antimony + Arsenic + Barium + Beryllium +
#     Bismuth + Cadmium + Cesium + Gadolinium + Lead + Mercury +
#     Nickel + Palladium + Platinum + Tellurium + Thallium + Thorium +
#     Tin + Tungsten + Uranium + Boron + Calcium + Chromium + Cobalt +
#     Copper + Iron + Lithium + Magnesium + Manganese + Molybdenum +
#     Phosphorus + Potassium + Selenium + Sodium + Strontium +
#     Sulfur + Vanadium + Zinc + Creatinine
#
#
# Step:  AIC=-134.37
# Status ~ Type + Aluminum + Antimony + Arsenic + Barium + Beryllium +
#     Bismuth + Cadmium + Cesium + Gadolinium + Lead + Mercury +
#     Nickel + Palladium + Platinum + Tellurium + Thallium + Tin +
#     Tungsten + Uranium + Boron + Calcium + Chromium + Cobalt +
#     Copper + Iron + Lithium + Magnesium + Manganese + Molybdenum +
#     Phosphorus + Potassium + Selenium + Sodium + Strontium +
#     Sulfur + Vanadium + Zinc + Creatinine
#
#
# Step:  AIC=-134.37
# Status ~ Type + Aluminum + Antimony + Arsenic + Barium + Beryllium +
#     Bismuth + Cadmium + Cesium + Gadolinium + Lead + Mercury +
#     Nickel + Palladium + Platinum + Thallium + Tin + Tungsten +
#     Uranium + Boron + Calcium + Chromium + Cobalt + Copper +
#     Iron + Lithium + Magnesium + Manganese + Molybdenum + Phosphorus +
#     Potassium + Selenium + Sodium + Strontium + Sulfur + Vanadium +
#     Zinc + Creatinine
#
#
# Step:  AIC=-134.37
# Status ~ Type + Aluminum + Antimony + Arsenic + Barium + Beryllium +
#     Bismuth + Cadmium + Cesium + Gadolinium + Lead + Mercury +
#     Nickel + Palladium + Thallium + Tin + Tungsten + Uranium +
#     Boron + Calcium + Chromium + Cobalt + Copper + Iron + Lithium +
#     Magnesium + Manganese + Molybdenum + Phosphorus + Potassium +
#     Selenium + Sodium + Strontium + Sulfur + Vanadium + Zinc +
#     Creatinine
#
#
# Step:  AIC=-134.37
# Status ~ Type + Aluminum + Antimony + Arsenic + Barium + Beryllium +
#     Bismuth + Cadmium + Cesium + Gadolinium + Lead + Mercury +
#     Nickel + Thallium + Tin + Tungsten + Uranium + Boron + Calcium +
#     Chromium + Cobalt + Copper + Iron + Lithium + Magnesium +
#     Manganese + Molybdenum + Phosphorus + Potassium + Selenium +
#     Sodium + Strontium + Sulfur + Vanadium + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Nickel      1   0.00067 14.433 -136.37
# - Aluminum    1   0.00396 14.436 -136.34
# - Phosphorus  1   0.00826 14.441 -136.31
# - Chromium    1   0.01606 14.448 -136.26
# - Arsenic     1   0.02563 14.458 -136.19
# - Vanadium    1   0.02600 14.458 -136.18
# - Copper      1   0.03587 14.468 -136.11
# - Barium      1   0.05204 14.484 -135.99
# - Lithium     1   0.06192 14.494 -135.92
# - Zinc        1   0.07149 14.504 -135.85
# - Strontium   1   0.07843 14.511 -135.80
# - Tungsten    1   0.08016 14.512 -135.79
# - Potassium   1   0.08035 14.513 -135.79
# - Mercury     1   0.08277 14.515 -135.77
# - Selenium    1   0.11619 14.548 -135.53
# - Magnesium   1   0.13215 14.564 -135.41
# - Uranium     1   0.15245 14.585 -135.27
# - Sulfur      1   0.16745 14.600 -135.16
# - Molybdenum  1   0.20653 14.639 -134.88
# - Cobalt      1   0.20851 14.641 -134.87
# - Manganese   1   0.21493 14.647 -134.82
# - Calcium     1   0.23869 14.671 -134.65
# - Sodium      1   0.24337 14.676 -134.62
# - Creatinine  1   0.25094 14.683 -134.56
# <none>                    14.432 -134.37
# - Cadmium     1   0.31136 14.744 -134.13
#  [ reached getOption("max.print") -- omitted 11 rows ]
#
# Step:  AIC=-136.37
# Status ~ Type + Aluminum + Antimony + Arsenic + Barium + Beryllium +
#     Bismuth + Cadmium + Cesium + Gadolinium + Lead + Mercury +
#     Thallium + Tin + Tungsten + Uranium + Boron + Calcium + Chromium +
#     Cobalt + Copper + Iron + Lithium + Magnesium + Manganese +
#     Molybdenum + Phosphorus + Potassium + Selenium + Sodium +
#     Strontium + Sulfur + Vanadium + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Aluminum    1   0.00350 14.436 -138.34
# - Phosphorus  1   0.00959 14.443 -138.30
# - Chromium    1   0.01573 14.449 -138.25
# - Arsenic     1   0.02503 14.458 -138.19
# - Vanadium    1   0.02557 14.458 -138.18
# - Copper      1   0.03917 14.472 -138.08
# - Lithium     1   0.06180 14.495 -137.92
# - Barium      1   0.06575 14.499 -137.89
# - Potassium   1   0.08099 14.514 -137.78
# - Tungsten    1   0.08102 14.514 -137.78
# - Zinc        1   0.08125 14.514 -137.78
# - Mercury     1   0.08275 14.516 -137.77
# - Strontium   1   0.08357 14.516 -137.76
# - Selenium    1   0.11695 14.550 -137.52
# - Uranium     1   0.15221 14.585 -137.27
# - Sulfur      1   0.16797 14.601 -137.15
# - Magnesium   1   0.17637 14.609 -137.09
# - Molybdenum  1   0.21059 14.643 -136.85
# - Manganese   1   0.21433 14.647 -136.82
# - Cobalt      1   0.21574 14.649 -136.81
# - Calcium     1   0.24002 14.673 -136.64
# - Sodium      1   0.24304 14.676 -136.61
# - Creatinine  1   0.25963 14.693 -136.50
# <none>                    14.433 -136.37
# - Cadmium     1   0.31247 14.745 -136.12
# - Antimony    1   0.35142 14.784 -135.84
#  [ reached getOption("max.print") -- omitted 10 rows ]
#
# Step:  AIC=-138.34
# Status ~ Type + Antimony + Arsenic + Barium + Beryllium + Bismuth +
#     Cadmium + Cesium + Gadolinium + Lead + Mercury + Thallium +
#     Tin + Tungsten + Uranium + Boron + Calcium + Chromium + Cobalt +
#     Copper + Iron + Lithium + Magnesium + Manganese + Molybdenum +
#     Phosphorus + Potassium + Selenium + Sodium + Strontium +
#     Sulfur + Vanadium + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Phosphorus  1   0.01180 14.448 -140.26
# - Chromium    1   0.01684 14.453 -140.22
# - Arsenic     1   0.02561 14.462 -140.16
# - Vanadium    1   0.02630 14.463 -140.15
# - Copper      1   0.04085 14.477 -140.04
# - Lithium     1   0.06146 14.498 -139.90
# - Barium      1   0.06397 14.500 -139.88
# - Potassium   1   0.07866 14.515 -139.77
# - Tungsten    1   0.08672 14.523 -139.71
# - Zinc        1   0.09037 14.527 -139.69
# - Strontium   1   0.09425 14.531 -139.66
# - Mercury     1   0.09445 14.531 -139.66
# - Selenium    1   0.11666 14.553 -139.50
# - Uranium     1   0.14871 14.585 -139.27
# - Magnesium   1   0.18211 14.618 -139.03
# - Sulfur      1   0.19420 14.631 -138.94
# - Cobalt      1   0.21393 14.650 -138.80
# - Molybdenum  1   0.21484 14.651 -138.79
# - Manganese   1   0.23508 14.671 -138.65
# - Sodium      1   0.24849 14.685 -138.55
# - Calcium     1   0.24956 14.686 -138.54
# - Creatinine  1   0.26860 14.705 -138.41
# <none>                    14.436 -138.34
# - Cadmium     1   0.30962 14.746 -138.11
# - Thallium    1   0.36253 14.799 -137.74
# - Antimony    1   0.36475 14.801 -137.72
#  [ reached getOption("max.print") -- omitted 9 rows ]
#
# Step:  AIC=-140.26
# Status ~ Type + Antimony + Arsenic + Barium + Beryllium + Bismuth +
#     Cadmium + Cesium + Gadolinium + Lead + Mercury + Thallium +
#     Tin + Tungsten + Uranium + Boron + Calcium + Chromium + Cobalt +
#     Copper + Iron + Lithium + Magnesium + Manganese + Molybdenum +
#     Potassium + Selenium + Sodium + Strontium + Sulfur + Vanadium +
#     Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Chromium    1   0.01649 14.465 -142.14
# - Vanadium    1   0.02545 14.474 -142.07
# - Arsenic     1   0.02838 14.477 -142.05
# - Copper      1   0.04569 14.494 -141.93
# - Lithium     1   0.06322 14.511 -141.80
# - Barium      1   0.06377 14.512 -141.79
# - Tungsten    1   0.08017 14.528 -141.68
# - Potassium   1   0.08280 14.531 -141.66
# - Zinc        1   0.08603 14.534 -141.63
# - Strontium   1   0.10100 14.549 -141.53
# - Mercury     1   0.10316 14.551 -141.51
# - Selenium    1   0.12676 14.575 -141.34
# - Uranium     1   0.15376 14.602 -141.15
# - Magnesium   1   0.17240 14.621 -141.01
# - Sulfur      1   0.21714 14.665 -140.69
# - Cobalt      1   0.23723 14.685 -140.55
# - Molybdenum  1   0.23922 14.687 -140.53
# - Manganese   1   0.26309 14.711 -140.36
# - Creatinine  1   0.26354 14.712 -140.36
# - Sodium      1   0.27584 14.724 -140.27
# <none>                    14.448 -140.26
# - Cadmium     1   0.31078 14.759 -140.02
# - Calcium     1   0.32289 14.771 -139.94
# - Thallium    1   0.35414 14.802 -139.71
# - Antimony    1   0.35794 14.806 -139.69
# - Bismuth     1   0.45747 14.906 -138.98
#  [ reached getOption("max.print") -- omitted 8 rows ]
#
# Step:  AIC=-142.14
# Status ~ Type + Antimony + Arsenic + Barium + Beryllium + Bismuth +
#     Cadmium + Cesium + Gadolinium + Lead + Mercury + Thallium +
#     Tin + Tungsten + Uranium + Boron + Calcium + Cobalt + Copper +
#     Iron + Lithium + Magnesium + Manganese + Molybdenum + Potassium +
#     Selenium + Sodium + Strontium + Sulfur + Vanadium + Zinc +
#     Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Vanadium    1   0.00926 14.474 -144.07
# - Arsenic     1   0.02227 14.487 -143.97
# - Copper      1   0.03557 14.500 -143.88
# - Barium      1   0.05461 14.519 -143.74
# - Lithium     1   0.05710 14.522 -143.72
# - Tungsten    1   0.07890 14.544 -143.56
# - Zinc        1   0.08238 14.547 -143.54
# - Mercury     1   0.09164 14.556 -143.47
# - Potassium   1   0.10136 14.566 -143.40
# - Strontium   1   0.10421 14.569 -143.38
# - Uranium     1   0.13817 14.603 -143.14
# - Selenium    1   0.14719 14.612 -143.07
# - Magnesium   1   0.15788 14.623 -143.00
# - Sulfur      1   0.20078 14.665 -142.69
# - Cobalt      1   0.22795 14.693 -142.50
# - Molybdenum  1   0.23267 14.697 -142.46
# - Creatinine  1   0.25330 14.718 -142.31
# <none>                    14.465 -142.14
# - Manganese   1   0.29435 14.759 -142.02
# - Sodium      1   0.30771 14.772 -141.93
# - Cadmium     1   0.30928 14.774 -141.91
# - Calcium     1   0.31682 14.781 -141.86
# - Antimony    1   0.34215 14.807 -141.68
# - Thallium    1   0.44319 14.908 -140.97
# - Bismuth     1   0.45218 14.917 -140.90
# - Tin         1   0.49183 14.957 -140.63
#  [ reached getOption("max.print") -- omitted 7 rows ]
#
# Step:  AIC=-144.07
# Status ~ Type + Antimony + Arsenic + Barium + Beryllium + Bismuth +
#     Cadmium + Cesium + Gadolinium + Lead + Mercury + Thallium +
#     Tin + Tungsten + Uranium + Boron + Calcium + Cobalt + Copper +
#     Iron + Lithium + Magnesium + Manganese + Molybdenum + Potassium +
#     Selenium + Sodium + Strontium + Sulfur + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Arsenic     1   0.02084 14.495 -145.92
# - Copper      1   0.04551 14.519 -145.74
# - Barium      1   0.05724 14.531 -145.66
# - Lithium     1   0.05992 14.534 -145.63
# - Tungsten    1   0.07048 14.544 -145.56
# - Zinc        1   0.07350 14.547 -145.54
# - Mercury     1   0.09701 14.571 -145.37
# - Potassium   1   0.09985 14.574 -145.35
# - Strontium   1   0.10224 14.576 -145.33
# - Selenium    1   0.14018 14.614 -145.06
# - Magnesium   1   0.15847 14.632 -144.93
# - Sulfur      1   0.20390 14.678 -144.60
# - Cobalt      1   0.22219 14.696 -144.47
# - Molybdenum  1   0.23688 14.711 -144.37
# - Uranium     1   0.24974 14.724 -144.27
# - Creatinine  1   0.26902 14.743 -144.14
# <none>                    14.474 -144.07
# - Cadmium     1   0.30104 14.775 -143.91
# - Calcium     1   0.31788 14.792 -143.79
# - Antimony    1   0.33669 14.811 -143.66
# - Manganese   1   0.33813 14.812 -143.65
# - Sodium      1   0.36785 14.842 -143.43
# - Thallium    1   0.44725 14.921 -142.87
# - Bismuth     1   0.45705 14.931 -142.81
# - Tin         1   0.48257 14.957 -142.63
# - Type        1   0.61716 15.091 -141.69
#  [ reached getOption("max.print") -- omitted 6 rows ]
#
# Step:  AIC=-145.92
# Status ~ Type + Antimony + Barium + Beryllium + Bismuth + Cadmium +
#     Cesium + Gadolinium + Lead + Mercury + Thallium + Tin + Tungsten +
#     Uranium + Boron + Calcium + Cobalt + Copper + Iron + Lithium +
#     Magnesium + Manganese + Molybdenum + Potassium + Selenium +
#     Sodium + Strontium + Sulfur + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Copper      1   0.03696 14.532 -147.65
# - Barium      1   0.06311 14.558 -147.46
# - Lithium     1   0.06376 14.559 -147.46
# - Tungsten    1   0.07459 14.569 -147.38
# - Zinc        1   0.08570 14.581 -147.30
# - Strontium   1   0.10946 14.604 -147.13
# - Mercury     1   0.11124 14.606 -147.12
# - Potassium   1   0.11788 14.613 -147.07
# - Selenium    1   0.12692 14.622 -147.00
# - Magnesium   1   0.14477 14.639 -146.88
# - Sulfur      1   0.21245 14.707 -146.39
# - Molybdenum  1   0.21977 14.714 -146.34
# - Cobalt      1   0.23810 14.733 -146.21
# - Uranium     1   0.24391 14.739 -146.17
# - Creatinine  1   0.27344 14.768 -145.96
# <none>                    14.495 -145.92
# - Cadmium     1   0.30879 14.804 -145.71
# - Antimony    1   0.31886 14.814 -145.63
# - Calcium     1   0.32408 14.819 -145.60
# - Manganese   1   0.35293 14.848 -145.39
# - Sodium      1   0.37002 14.865 -145.27
# - Bismuth     1   0.44168 14.936 -144.77
# - Thallium    1   0.46184 14.957 -144.62
# - Tin         1   0.48036 14.975 -144.50
# - Type        1   0.63189 15.127 -143.44
# - Iron        1   0.66901 15.164 -143.18
#  [ reached getOption("max.print") -- omitted 5 rows ]
#
# Step:  AIC=-147.65
# Status ~ Type + Antimony + Barium + Beryllium + Bismuth + Cadmium +
#     Cesium + Gadolinium + Lead + Mercury + Thallium + Tin + Tungsten +
#     Uranium + Boron + Calcium + Cobalt + Iron + Lithium + Magnesium +
#     Manganese + Molybdenum + Potassium + Selenium + Sodium +
#     Strontium + Sulfur + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Tungsten    1   0.06521 14.597 -149.18
# - Lithium     1   0.07679 14.608 -149.10
# - Mercury     1   0.08399 14.616 -149.05
# - Strontium   1   0.09170 14.623 -148.99
# - Barium      1   0.09893 14.631 -148.94
# - Potassium   1   0.11733 14.649 -148.81
# - Zinc        1   0.11812 14.650 -148.80
# - Magnesium   1   0.13772 14.669 -148.66
# - Sulfur      1   0.19882 14.730 -148.22
# - Selenium    1   0.19905 14.731 -148.22
# - Molybdenum  1   0.20387 14.736 -148.19
# - Uranium     1   0.22612 14.758 -148.03
# - Cobalt      1   0.26166 14.793 -147.78
# - Creatinine  1   0.26432 14.796 -147.76
# <none>                    14.532 -147.65
# - Calcium     1   0.29746 14.829 -147.52
# - Cadmium     1   0.31995 14.852 -147.36
# - Manganese   1   0.34901 14.881 -147.16
# - Antimony    1   0.35561 14.887 -147.11
# - Sodium      1   0.36845 14.900 -147.02
# - Bismuth     1   0.42288 14.955 -146.64
# - Thallium    1   0.47093 15.003 -146.30
# - Tin         1   0.48912 15.021 -146.18
# - Type        1   0.62403 15.156 -145.24
# - Iron        1   0.66471 15.196 -144.95
# - Gadolinium  1   0.67782 15.210 -144.86
#  [ reached getOption("max.print") -- omitted 4 rows ]
#
# Step:  AIC=-149.18
# Status ~ Type + Antimony + Barium + Beryllium + Bismuth + Cadmium +
#     Cesium + Gadolinium + Lead + Mercury + Thallium + Tin + Uranium +
#     Boron + Calcium + Cobalt + Iron + Lithium + Magnesium + Manganese +
#     Molybdenum + Potassium + Selenium + Sodium + Strontium +
#     Sulfur + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Strontium   1   0.05441 14.651 -150.79
# - Barium      1   0.08012 14.677 -150.61
# - Mercury     1   0.08269 14.680 -150.59
# - Lithium     1   0.08455 14.681 -150.57
# - Zinc        1   0.11363 14.711 -150.37
# - Potassium   1   0.13262 14.730 -150.23
# - Magnesium   1   0.18886 14.786 -149.83
# - Selenium    1   0.19615 14.793 -149.78
# - Sulfur      1   0.20878 14.806 -149.69
# - Uranium     1   0.21973 14.817 -149.61
# - Creatinine  1   0.27361 14.870 -149.23
# <none>                    14.597 -149.18
# - Cadmium     1   0.30656 14.903 -149.00
# - Calcium     1   0.31104 14.908 -148.97
# - Cobalt      1   0.32777 14.925 -148.85
# - Antimony    1   0.34398 14.941 -148.74
# - Sodium      1   0.34458 14.941 -148.73
# - Manganese   1   0.37203 14.969 -148.54
# - Bismuth     1   0.39881 14.996 -148.35
# - Molybdenum  1   0.42802 15.025 -148.15
# - Tin         1   0.46984 15.067 -147.85
# - Thallium    1   0.49714 15.094 -147.66
# - Type        1   0.58668 15.184 -147.04
# - Gadolinium  1   0.61678 15.214 -146.84
# - Cesium      1   0.67961 15.277 -146.40
# - Iron        1   0.74116 15.338 -145.98
#  [ reached getOption("max.print") -- omitted 3 rows ]
#
# Step:  AIC=-150.79
# Status ~ Type + Antimony + Barium + Beryllium + Bismuth + Cadmium +
#     Cesium + Gadolinium + Lead + Mercury + Thallium + Tin + Uranium +
#     Boron + Calcium + Cobalt + Iron + Lithium + Magnesium + Manganese +
#     Molybdenum + Potassium + Selenium + Sodium + Sulfur + Zinc +
#     Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Barium      1   0.06084 14.712 -152.35
# - Mercury     1   0.06909 14.720 -152.30
# - Zinc        1   0.13110 14.782 -151.85
# - Potassium   1   0.13766 14.789 -151.81
# - Lithium     1   0.16221 14.814 -151.63
# - Sulfur      1   0.17911 14.831 -151.51
# - Selenium    1   0.24383 14.895 -151.06
# - Magnesium   1   0.25098 14.902 -151.01
# - Calcium     1   0.25950 14.911 -150.95
# - Creatinine  1   0.26284 14.914 -150.92
# - Uranium     1   0.27538 14.927 -150.84
# <none>                    14.651 -150.79
# - Sodium      1   0.30214 14.954 -150.65
# - Cadmium     1   0.32581 14.977 -150.48
# - Antimony    1   0.33252 14.984 -150.43
# - Manganese   1   0.36423 15.016 -150.21
# - Cobalt      1   0.38263 15.034 -150.08
# - Bismuth     1   0.39286 15.044 -150.01
# - Molybdenum  1   0.41657 15.068 -149.85
# - Tin         1   0.46342 15.115 -149.52
# - Thallium    1   0.51209 15.163 -149.18
# - Type        1   0.56955 15.221 -148.79
# - Cesium      1   0.66922 15.321 -148.10
# - Iron        1   0.74280 15.394 -147.60
# - Beryllium   1   0.76448 15.416 -147.45
# - Boron       1   0.82839 15.480 -147.01
#  [ reached getOption("max.print") -- omitted 2 rows ]
#
# Step:  AIC=-152.35
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Mercury + Thallium + Tin + Uranium +
#     Boron + Calcium + Cobalt + Iron + Lithium + Magnesium + Manganese +
#     Molybdenum + Potassium + Selenium + Sodium + Sulfur + Zinc +
#     Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Mercury     1   0.06331 14.775 -153.90
# - Potassium   1   0.10405 14.816 -153.62
# - Zinc        1   0.12398 14.836 -153.47
# - Lithium     1   0.15076 14.863 -153.28
# - Sulfur      1   0.18994 14.902 -153.01
# - Selenium    1   0.19741 14.910 -152.96
# - Uranium     1   0.22690 14.939 -152.75
# - Magnesium   1   0.22920 14.941 -152.73
# - Creatinine  1   0.24964 14.962 -152.59
# <none>                    14.712 -152.35
# - Antimony    1   0.28587 14.998 -152.33
# - Manganese   1   0.30801 15.020 -152.18
# - Calcium     1   0.35289 15.065 -151.87
# - Cobalt      1   0.35558 15.068 -151.85
# - Cadmium     1   0.37059 15.083 -151.74
# - Bismuth     1   0.37378 15.086 -151.72
# - Sodium      1   0.40925 15.121 -151.47
# - Tin         1   0.42795 15.140 -151.34
# - Thallium    1   0.50438 15.217 -150.81
# - Type        1   0.52778 15.240 -150.65
# - Molybdenum  1   0.56703 15.279 -150.38
# - Cesium      1   0.63108 15.343 -149.94
# - Beryllium   1   0.75289 15.465 -149.11
# - Boron       1   0.77301 15.485 -148.98
# - Iron        1   0.80235 15.514 -148.78
# - Gadolinium  1   0.86193 15.574 -148.38
#  [ reached getOption("max.print") -- omitted 1 row ]
#
# Step:  AIC=-153.9
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Uranium + Boron + Calcium +
#     Cobalt + Iron + Lithium + Magnesium + Manganese + Molybdenum +
#     Potassium + Selenium + Sodium + Sulfur + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Potassium   1   0.11641 14.892 -155.08
# - Lithium     1   0.13945 14.915 -154.92
# - Zinc        1   0.15110 14.927 -154.84
# - Selenium    1   0.19352 14.969 -154.54
# - Sulfur      1   0.19841 14.974 -154.50
# - Magnesium   1   0.20723 14.983 -154.44
# - Creatinine  1   0.21734 14.993 -154.37
# - Antimony    1   0.26048 15.036 -154.07
# - Uranium     1   0.27585 15.051 -153.96
# <none>                    14.775 -153.90
# - Bismuth     1   0.31222 15.088 -153.71
# - Calcium     1   0.32717 15.103 -153.60
# - Manganese   1   0.33662 15.112 -153.54
# - Cobalt      1   0.37409 15.150 -153.28
# - Tin         1   0.43636 15.212 -152.85
# - Sodium      1   0.43710 15.213 -152.84
# - Cadmium     1   0.50077 15.276 -152.40
# - Molybdenum  1   0.56300 15.338 -151.98
# - Type        1   0.56965 15.345 -151.93
# - Thallium    1   0.60930 15.385 -151.66
# - Cesium      1   0.70176 15.477 -151.03
# - Beryllium   1   0.72949 15.505 -150.84
# - Iron        1   0.77569 15.551 -150.53
# - Gadolinium  1   0.88217 15.658 -149.81
# - Boron       1   0.91171 15.687 -149.62
# - Lead        1   1.18806 15.964 -147.78
#
# Step:  AIC=-155.08
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Uranium + Boron + Calcium +
#     Cobalt + Iron + Lithium + Magnesium + Manganese + Molybdenum +
#     Selenium + Sodium + Sulfur + Zinc + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Zinc        1   0.10188 14.994 -156.36
# - Lithium     1   0.16479 15.057 -155.92
# - Sulfur      1   0.17770 15.070 -155.83
# - Uranium     1   0.18946 15.081 -155.75
# - Creatinine  1   0.24149 15.133 -155.39
# - Manganese   1   0.24983 15.142 -155.33
# - Magnesium   1   0.28573 15.178 -155.08
# <none>                    14.892 -155.08
# - Bismuth     1   0.29608 15.188 -155.01
# - Selenium    1   0.29873 15.191 -154.99
# - Calcium     1   0.32346 15.215 -154.82
# - Cobalt      1   0.35503 15.247 -154.61
# - Antimony    1   0.41427 15.306 -154.20
# - Type        1   0.47487 15.367 -153.78
# - Thallium    1   0.51285 15.405 -153.53
# - Sodium      1   0.52795 15.420 -153.42
# - Cadmium     1   0.56127 15.453 -153.19
# - Cesium      1   0.58690 15.479 -153.02
# - Tin         1   0.62171 15.514 -152.78
# - Molybdenum  1   0.72795 15.620 -152.07
# - Beryllium   1   0.77850 15.670 -151.73
# - Boron       1   0.79708 15.689 -151.60
# - Iron        1   0.79931 15.691 -151.59
# - Gadolinium  1   0.94640 15.838 -150.61
# - Lead        1   1.10391 15.996 -149.57
#
# Step:  AIC=-156.36
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Uranium + Boron + Calcium +
#     Cobalt + Iron + Lithium + Magnesium + Manganese + Molybdenum +
#     Selenium + Sodium + Sulfur + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Uranium     1   0.15031 15.144 -157.32
# - Sulfur      1   0.18465 15.178 -157.08
# - Lithium     1   0.20810 15.202 -156.92
# - Magnesium   1   0.27377 15.268 -156.46
# <none>                    14.994 -156.36
# - Manganese   1   0.30194 15.296 -156.27
# - Bismuth     1   0.31508 15.309 -156.18
# - Creatinine  1   0.32804 15.322 -156.09
# - Calcium     1   0.33638 15.330 -156.03
# - Selenium    1   0.34816 15.342 -155.95
# - Antimony    1   0.36092 15.355 -155.87
# - Cobalt      1   0.37070 15.364 -155.80
# - Type        1   0.40132 15.395 -155.59
# - Thallium    1   0.47468 15.469 -155.09
# - Sodium      1   0.47716 15.471 -155.07
# - Cadmium     1   0.50315 15.497 -154.90
# - Cesium      1   0.66211 15.656 -153.83
# - Tin         1   0.71644 15.710 -153.46
# - Molybdenum  1   0.73756 15.731 -153.32
# - Iron        1   0.77151 15.765 -153.10
# - Boron       1   0.80414 15.798 -152.88
# - Beryllium   1   0.87254 15.866 -152.43
# - Gadolinium  1   0.96169 15.956 -151.84
# - Lead        1   1.11556 16.109 -150.83
#
# Step:  AIC=-157.32
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Boron + Calcium + Cobalt +
#     Iron + Lithium + Magnesium + Manganese + Molybdenum + Selenium +
#     Sodium + Sulfur + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Lithium     1   0.17595 15.320 -158.10
# - Sulfur      1   0.24959 15.394 -157.60
# - Magnesium   1   0.26785 15.412 -157.48
# - Manganese   1   0.27838 15.422 -157.40
# - Selenium    1   0.28448 15.429 -157.36
# <none>                    15.144 -157.32
# - Antimony    1   0.32474 15.469 -157.09
# - Calcium     1   0.33728 15.481 -157.00
# - Creatinine  1   0.34498 15.489 -156.95
# - Bismuth     1   0.34839 15.492 -156.93
# - Cobalt      1   0.38805 15.532 -156.66
# - Type        1   0.38951 15.534 -156.65
# - Cadmium     1   0.47780 15.622 -156.06
# - Sodium      1   0.49953 15.644 -155.91
# - Thallium    1   0.53522 15.679 -155.67
# - Cesium      1   0.54049 15.685 -155.63
# - Tin         1   0.59329 15.737 -155.28
# - Boron       1   0.67429 15.818 -154.74
# - Molybdenum  1   0.75495 15.899 -154.21
# - Iron        1   0.76274 15.907 -154.16
# - Gadolinium  1   0.91094 16.055 -153.18
# - Beryllium   1   0.94628 16.090 -152.95
# - Lead        1   1.02603 16.170 -152.43
#
# Step:  AIC=-158.1
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Boron + Calcium + Cobalt +
#     Iron + Magnesium + Manganese + Molybdenum + Selenium + Sodium +
#     Sulfur + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Sulfur      1   0.20469 15.525 -158.71
# - Magnesium   1   0.24470 15.565 -158.44
# - Selenium    1   0.26307 15.583 -158.32
# - Calcium     1   0.26603 15.586 -158.30
# - Creatinine  1   0.27926 15.599 -158.21
# - Antimony    1   0.29234 15.612 -158.12
# - Cobalt      1   0.29288 15.613 -158.12
# <none>                    15.320 -158.10
# - Bismuth     1   0.29961 15.620 -158.07
# - Manganese   1   0.34090 15.661 -157.79
# - Type        1   0.36369 15.684 -157.64
# - Cadmium     1   0.39612 15.716 -157.42
# - Thallium    1   0.41982 15.740 -157.26
# - Sodium      1   0.47673 15.797 -156.89
# - Tin         1   0.53523 15.855 -156.50
# - Cesium      1   0.61959 15.940 -155.94
# - Iron        1   0.66259 15.983 -155.66
# - Boron       1   0.68203 16.002 -155.53
# - Molybdenum  1   0.68349 16.003 -155.52
# - Beryllium   1   0.91366 16.234 -154.02
# - Gadolinium  1   0.98548 16.305 -153.56
# - Lead        1   0.99868 16.319 -153.47
#
# Step:  AIC=-158.71
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Boron + Calcium + Cobalt +
#     Iron + Magnesium + Manganese + Molybdenum + Selenium + Sodium +
#     Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Magnesium   1   0.14976 15.675 -159.70
# - Creatinine  1   0.21538 15.740 -159.26
# - Bismuth     1   0.26938 15.794 -158.90
# <none>                    15.525 -158.71
# - Cobalt      1   0.32650 15.851 -158.53
# - Calcium     1   0.34149 15.866 -158.43
# - Sodium      1   0.37711 15.902 -158.19
# - Thallium    1   0.37962 15.904 -158.17
# - Manganese   1   0.42680 15.951 -157.86
# - Cadmium     1   0.44045 15.965 -157.77
# - Cesium      1   0.48960 16.014 -157.45
# - Type        1   0.49945 16.024 -157.38
# - Antimony    1   0.53019 16.055 -157.18
# - Boron       1   0.53074 16.055 -157.18
# - Beryllium   1   0.75266 16.277 -155.74
# - Iron        1   0.79175 16.317 -155.49
# - Molybdenum  1   0.79339 16.318 -155.48
# - Tin         1   0.82061 16.345 -155.30
# - Gadolinium  1   1.04439 16.569 -153.87
# - Lead        1   1.33792 16.863 -152.03
# - Selenium    1   1.75427 17.279 -149.47
#
# Step:  AIC=-159.7
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Boron + Calcium + Cobalt +
#     Iron + Manganese + Molybdenum + Selenium + Sodium + Creatinine
#
#              Df Sum of Sq    RSS     AIC
# - Creatinine  1   0.18438 15.859 -160.47
# - Calcium     1   0.23688 15.911 -160.13
# - Cobalt      1   0.28715 15.962 -159.80
# - Bismuth     1   0.29003 15.964 -159.78
# <none>                    15.675 -159.70
# - Sodium      1   0.33650 16.011 -159.47
# - Manganese   1   0.34267 16.017 -159.43
# - Thallium    1   0.34319 16.018 -159.43
# - Boron       1   0.40941 16.084 -159.00
# - Antimony    1   0.41908 16.094 -158.93
# - Cadmium     1   0.45554 16.130 -158.69
# - Cesium      1   0.56632 16.241 -157.97
# - Iron        1   0.66736 16.342 -157.32
# - Beryllium   1   0.69769 16.372 -157.13
# - Tin         1   0.80995 16.485 -156.41
# - Molybdenum  1   0.81496 16.489 -156.38
# - Gadolinium  1   0.93670 16.611 -155.61
# - Type        1   1.16951 16.844 -154.15
# - Lead        1   1.33121 17.006 -153.14
# - Selenium    1   1.64277 17.317 -151.24
#
# Step:  AIC=-160.47
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Boron + Calcium + Cobalt +
#     Iron + Manganese + Molybdenum + Selenium + Sodium
#
#              Df Sum of Sq    RSS     AIC
# - Calcium     1   0.19152 16.050 -161.21
# <none>                    15.859 -160.47
# - Cobalt      1   0.32402 16.183 -160.35
# - Manganese   1   0.33295 16.192 -160.29
# - Bismuth     1   0.35464 16.213 -160.15
# - Thallium    1   0.37134 16.230 -160.04
# - Boron       1   0.44367 16.303 -159.58
# - Sodium      1   0.45391 16.313 -159.51
# - Antimony    1   0.49846 16.357 -159.22
# - Cadmium     1   0.51035 16.369 -159.15
# - Cesium      1   0.53466 16.393 -158.99
# - Iron        1   0.59380 16.453 -158.62
# - Beryllium   1   0.64111 16.500 -158.31
# - Molybdenum  1   0.80297 16.662 -157.29
# - Tin         1   0.86389 16.723 -156.91
# - Gadolinium  1   0.88481 16.744 -156.77
# - Type        1   1.16655 17.025 -155.02
# - Lead        1   1.32857 17.188 -154.03
# - Selenium    1   1.83453 17.693 -150.98
#
# Step:  AIC=-161.21
# Status ~ Type + Antimony + Beryllium + Bismuth + Cadmium + Cesium +
#     Gadolinium + Lead + Thallium + Tin + Boron + Cobalt + Iron +
#     Manganese + Molybdenum + Selenium + Sodium
#
#              Df Sum of Sq    RSS     AIC
# <none>                    16.050 -161.21
# - Thallium    1   0.31409 16.364 -161.18
# - Cobalt      1   0.33467 16.385 -161.05
# - Bismuth     1   0.35550 16.406 -160.91
# - Antimony    1   0.36166 16.412 -160.87
# - Manganese   1   0.47677 16.527 -160.14
# - Cadmium     1   0.48019 16.531 -160.12
# - Boron       1   0.48620 16.537 -160.08
# - Sodium      1   0.49377 16.544 -160.03
# - Beryllium   1   0.53256 16.583 -159.79
# - Cesium      1   0.55810 16.608 -159.62
# - Molybdenum  1   0.66904 16.720 -158.93
# - Gadolinium  1   0.81757 16.868 -158.00
# - Tin         1   0.82864 16.879 -157.93
# - Type        1   1.21316 17.264 -155.56
# - Lead        1   1.29218 17.343 -155.08
# - Iron        1   1.73098 17.781 -152.46
# - Selenium    1   2.22213 18.273 -149.60
# Call:
# lm(formula = Status ~ Type + Antimony + Beryllium + Bismuth +
#     Cadmium + Cesium + Gadolinium + Lead + Thallium + Tin + Boron +
#     Cobalt + Iron + Manganese + Molybdenum + Selenium + Sodium,
#     data = data1)
#
# Coefficients:
# (Intercept)        Type1     Antimony    Beryllium      Bismuth      Cadmium
#  -4.458e-01    4.307e-01   -5.989e-01    5.623e+02    3.848e-02   -6.465e-01
#      Cesium   Gadolinium         Lead     Thallium          Tin        Boron
#  -4.172e-02   -2.919e-02    5.376e-01   -7.473e-01    6.059e-02    6.925e-02
#      Cobalt         Iron    Manganese   Molybdenum     Selenium       Sodium
#   1.245e+02   -9.181e-01   -8.173e+01    2.070e+00    6.154e+00    8.913e-04

# %% [markdown]
# ### Toxic: Antimony + Beryllium + Bismuth + Cadmium + Cesium + Gadolinium + Lead + Thallium + Tin
# ### Essential: Boron + Cobalt + Iron + Manganese + Molybdenum + Selenium + Sodium
